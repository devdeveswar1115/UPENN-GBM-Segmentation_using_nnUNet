# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import nibabel as nib
import numpy as np
import os
import pathlib

# %%
base_img_path = '/content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/'
tr_label_files = os.listdir(base_img_path)
tr_label_files.sort()
# print(tr_label_files)
print(len(tr_label_files))
# Out:
# 117

# %%
for file in tr_label_files:

  file_name = base_img_path + file
  # Load image
  img = nib.load(file_name)
  print("-"*100)
  print ("Patient label file: ", file)

  # Store image as a numpy array
  img_data = img.get_fdata()

  # Check array min, max and unique values for image label values
  print("Before label check")
  print(np.amin(img_data),np.amax(img_data))
  print(np.unique(img_data))
# Out:
# ----------------------------------------------------------------------------------------------------
# Patient label file:  100.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  102.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  105.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  106.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  107.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  108.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  11.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  112.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  113.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  115.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  118.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  119.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  121.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  122.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  13.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  131.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  134.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  136.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  137.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  138.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  139.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  14.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  140.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  141.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  143.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  146.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  147.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  148.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  149.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  154.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  158.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  16.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  17.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  172.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  176.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  178.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  180.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  192.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  193.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  196.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  197.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  2.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  205.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  206.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  208.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  21.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  215.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  217.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  226.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  227.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  238.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  240.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  249.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  251.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  252.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  253.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  256.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  259.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  261.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  262.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  264.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  266.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  274.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  277.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  284.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  285.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  29.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  290.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  294.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  30.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  31.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  312.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  33.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  330.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  344.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  356.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  360.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  362.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  367.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  368.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  371.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  373.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  375.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  376.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  384.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  388.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  391.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  393.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  398.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  40.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  402.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  404.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  41.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  418.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  428.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  430.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  437.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  439.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  474.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  54.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  59.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  6.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  60.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  62.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  66.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  69.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  73.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  75.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  76.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  80.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  82.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  83.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  86.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  88.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  9.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  91.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# ----------------------------------------------------------------------------------------------------
# Patient label file:  96.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]

# %%
for file in tr_label_files:

  file_name = base_img_path + file
  # Load image
  img = nib.load(file_name)
  print("-"*100)
  print ("Patient label file: ", file)

  # Store image as a numpy array
  img_data = img.get_fdata()

  # Check array min, max and unique values for image
  print("Before label check")
  print(np.amin(img_data),np.amax(img_data))
  print(np.unique(img_data))

  # Where label is 4, reset it to 3 so nnUnet doesnt complain about non-consecutive labels
  img_data[(img_data == 4.0)] = 3

  # Check min, max and unique values again
  print("After label conversion")
  print(np.amin(img_data),np.amax(img_data))
  print(np.unique(img_data))

  # Convert array back to Nii image
  new_img = nib.Nifti1Image(img_data, img.affine, img.header)

  # Set up new image path
  new_img_path = base_img_path + file
  print ('Saved to: ' + new_img_path)
  # Save image to out_dir_path
  nib.save(new_img, new_img_path)
# Out:
# ----------------------------------------------------------------------------------------------------
# Patient label file:  100.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/100.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  102.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/102.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  105.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/105.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  106.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/106.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  107.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/107.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  108.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/108.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  11.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/11.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  112.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/112.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  113.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/113.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  115.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/115.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  118.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/118.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  119.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/119.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  121.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/121.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  122.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/122.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  13.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/13.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  131.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/131.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  134.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/134.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  136.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/136.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  137.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/137.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  138.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/138.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  139.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/139.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  14.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/14.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  140.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/140.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  141.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/141.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  143.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/143.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  146.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/146.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  147.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/147.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  148.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/148.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  149.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/149.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  154.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/154.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  158.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/158.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  16.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/16.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  17.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/17.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  172.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/172.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  176.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/176.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  178.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/178.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  180.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/180.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  192.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/192.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  193.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/193.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  196.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/196.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  197.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/197.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  2.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/2.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  205.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/205.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  206.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/206.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  208.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/208.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  21.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/21.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  215.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/215.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  217.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/217.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  226.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/226.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  227.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/227.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  238.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/238.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  240.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/240.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  249.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/249.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  251.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/251.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  252.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/252.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  253.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/253.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  256.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/256.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  259.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/259.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  261.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/261.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  262.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/262.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  264.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/264.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  266.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/266.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  274.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/274.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  277.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/277.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  284.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/284.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  285.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/285.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  29.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/29.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  290.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/290.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  294.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/294.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  30.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/30.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  31.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/31.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  312.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/312.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  33.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/33.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  330.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/330.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  344.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/344.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  356.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/356.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  360.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/360.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  362.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/362.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  367.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/367.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  368.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/368.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  371.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/371.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  373.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/373.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  375.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/375.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  376.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/376.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  384.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/384.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  388.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/388.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  391.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/391.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  393.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/393.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  398.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/398.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  40.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/40.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  402.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/402.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  404.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/404.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  41.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/41.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  418.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/418.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  428.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/428.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  430.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/430.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  437.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/437.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  439.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/439.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  474.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/474.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  54.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/54.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  59.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/59.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  6.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/6.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  60.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/60.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  62.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/62.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  66.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/66.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  69.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/69.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  73.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/73.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  75.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/75.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  76.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/76.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  80.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/80.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  82.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/82.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  83.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/83.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  86.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/86.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  88.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/88.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  9.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/9.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  91.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/91.nii.gz
# ----------------------------------------------------------------------------------------------------
# Patient label file:  96.nii.gz
# Before label check
# 0.0 4.0
# [0. 1. 2. 4.]
# After label conversion
# 0.0 3.0
# [0. 1. 2. 3.]
# Saved to: /content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma/labelsTr/96.nii.gz

# %% [markdown]
# MetaData

# %%
# !pip install batchgenerators
# Out:
# Collecting batchgenerators
#   Downloading batchgenerators-0.25.tar.gz (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 718.1 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from batchgenerators) (10.4.0)
# Requirement already satisfied: numpy>=1.10.2 in /usr/local/lib/python3.10/dist-packages (from batchgenerators) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from batchgenerators) (1.13.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from batchgenerators) (0.23.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from batchgenerators) (1.3.2)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from batchgenerators) (1.0.0)
# Collecting unittest2 (from batchgenerators)
#   Downloading unittest2-1.1.0-py2.py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: threadpoolctl in /usr/local/lib/python3.10/dist-packages (from batchgenerators) (3.5.0)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image->batchgenerators) (3.3)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->batchgenerators) (2.35.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->batchgenerators) (2024.8.30)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image->batchgenerators) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->batchgenerators) (0.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->batchgenerators) (1.4.2)
# Collecting argparse (from unittest2->batchgenerators)
#   Downloading argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: six>=1.4 in /usr/local/lib/python3.10/dist-packages (from unittest2->batchgenerators) (1.16.0)
# Collecting traceback2 (from unittest2->batchgenerators)
#   Downloading traceback2-1.4.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting linecache2 (from traceback2->unittest2->batchgenerators)
#   Downloading linecache2-1.0.0-py2.py3-none-any.whl.metadata (1000 bytes)
# Downloading unittest2-1.1.0-py2.py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 1.7 MB/s eta 0:00:00
# Downloading argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Downloading traceback2-1.4.0-py2.py3-none-any.whl (16 kB)
# Downloading linecache2-1.0.0-py2.py3-none-any.whl (12 kB)
# Building wheels for collected packages: batchgenerators
#   Building wheel for batchgenerators (setup.py) ... done
#   Created wheel for batchgenerators: filename=batchgenerators-0.25-py3-none-any.whl size=89008 sha256=16258c9568982daa558860d869ef042a1b6ad649e77726038ce5f25873c4cb85
#   Stored in directory: /root/.cache/pip/wheels/9e/b0/1b/40912fb58eb167b86cbc444ddb2e6ba382b248215295f932e2
# Successfully built batchgenerators
# Installing collected packages: linecache2, argparse, traceback2, unittest2, batchgenerators
# Successfully installed argparse-1.4.0 batchgenerators-0.25 linecache2-1.0.0 traceback2-1.4.0 unittest2-1.1.0

# %%
# !pip install nnunetv2
# Out:
# Collecting nnunetv2
#   Downloading nnunetv2-2.5.1.tar.gz (196 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.0/197.0 kB 1.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=2.1.2 in /usr/local/lib/python3.10/dist-packages (from nnunetv2) (2.4.1+cu121)
# Collecting acvl-utils<0.3,>=0.2 (from nnunetv2)
#   Downloading acvl_utils-0.2.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Collecting dynamic-network-architectures<0.4,>=0.3.1 (from nnunetv2)
#   Downloading dynamic_network_architectures-0.3.1.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nnunetv2) (4.66.5)
# Collecting dicom2nifti (from nnunetv2)
#   Downloading dicom2nifti-2.4.11-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from nnunetv2) (1.13.1)
# Requirement already satisfied: batchgenerators>=0.25 in /usr/local/lib/python3.10/dist-packages (from nnunetv2) (0.25)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from nnunetv2) (1.26.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from nnunetv2) (1.3.2)
# Requirement already satisfied: scikit-image>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from nnunetv2) (0.23.2)
# Collecting SimpleITK>=2.2.1 (from nnunetv2)
#   Downloading SimpleITK-2.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.9 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from nnunetv2) (2.1.4)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from nnunetv2) (0.20.3)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.10/dist-packages (from nnunetv2) (2024.8.30)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from nnunetv2) (2.32.3)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.10/dist-packages (from nnunetv2) (5.2.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from nnunetv2) (3.7.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from nnunetv2) (0.13.1)
# Collecting imagecodecs (from nnunetv2)
#   Downloading imagecodecs-2024.9.22-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting yacs (from nnunetv2)
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Collecting batchgeneratorsv2>=0.2 (from nnunetv2)
#   Downloading batchgeneratorsv2-0.2.1.tar.gz (34 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from nnunetv2) (0.8.0)
# Collecting connected-components-3d (from acvl-utils<0.3,>=0.2->nnunetv2)
#   Downloading connected_components_3d-3.18.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from batchgenerators>=0.25->nnunetv2) (10.4.0)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from batchgenerators>=0.25->nnunetv2) (1.0.0)
# Requirement already satisfied: unittest2 in /usr/local/lib/python3.10/dist-packages (from batchgenerators>=0.25->nnunetv2) (1.1.0)
# Requirement already satisfied: threadpoolctl in /usr/local/lib/python3.10/dist-packages (from batchgenerators>=0.25->nnunetv2) (3.5.0)
# Collecting fft-conv-pytorch (from batchgeneratorsv2>=0.2->nnunetv2)
#   Downloading fft_conv_pytorch-1.2.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.19.3->nnunetv2) (3.3)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.19.3->nnunetv2) (2.35.1)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.19.3->nnunetv2) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.19.3->nnunetv2) (0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->nnunetv2) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->nnunetv2) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->nnunetv2) (1.13.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->nnunetv2) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->nnunetv2) (2024.6.1)
# Collecting pydicom>=2.2.0 (from dicom2nifti->nnunetv2)
#   Downloading pydicom-3.0.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting python-gdcm (from dicom2nifti->nnunetv2)
#   Downloading python_gdcm-3.0.24.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.7 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nnunetv2) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nnunetv2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nnunetv2) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nnunetv2) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nnunetv2) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nnunetv2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->nnunetv2) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->nnunetv2) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->nnunetv2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->nnunetv2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->nnunetv2) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->nnunetv2) (2024.8.30)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->nnunetv2) (1.4.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from yacs->nnunetv2) (6.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->nnunetv2) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.1.2->nnunetv2) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2.1.2->nnunetv2) (1.3.0)
# Collecting argparse (from unittest2->batchgenerators>=0.25->nnunetv2)
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: traceback2 in /usr/local/lib/python3.10/dist-packages (from unittest2->batchgenerators>=0.25->nnunetv2) (1.4.0)
# Requirement already satisfied: linecache2 in /usr/local/lib/python3.10/dist-packages (from traceback2->unittest2->batchgenerators>=0.25->nnunetv2) (1.0.0)
# Downloading SimpleITK-2.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.4/52.4 MB 16.2 MB/s eta 0:00:00
# Downloading dicom2nifti-2.4.11-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.3 MB/s eta 0:00:00
# Downloading imagecodecs-2024.9.22-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 MB 15.6 MB/s eta 0:00:00
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading pydicom-3.0.1-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 73.5 MB/s eta 0:00:00
# Downloading connected_components_3d-3.18.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 83.8 MB/s eta 0:00:00
# Downloading fft_conv_pytorch-1.2.0-py3-none-any.whl (6.8 kB)
# Downloading python_gdcm-3.0.24.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 50.5 MB/s eta 0:00:00
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Building wheels for collected packages: nnunetv2, acvl-utils, batchgeneratorsv2, dynamic-network-architectures
#   Building wheel for nnunetv2 (pyproject.toml) ... done
#   Created wheel for nnunetv2: filename=nnunetv2-2.5.1-py3-none-any.whl size=264366 sha256=66dacbb9b763a2a97553e555ed78a9062a86012ab7a04839a9b753cbb24c625f
#   Stored in directory: /root/.cache/pip/wheels/5d/d6/90/88743b341922dc9f6795742570aac83a1eaa55f77ee676a5a6
#   Building wheel for acvl-utils (setup.py) ... done
#   Created wheel for acvl-utils: filename=acvl_utils-0.2-py3-none-any.whl size=22438 sha256=b0a8a5e70458d07ec3b8b6b09b0bb24a863223a536efca54c067b198702d7b24
#   Stored in directory: /root/.cache/pip/wheels/ad/f0/84/52e8897591e66339bd2796681b9540b6c5e453c1461fa92a9e
#   Building wheel for batchgeneratorsv2 (pyproject.toml) ... done
#   Created wheel for batchgeneratorsv2: filename=batchgeneratorsv2-0.2.1-py3-none-any.whl size=45184 sha256=e6d712df709799e729ca1dc665de7bbdb022bf1bc3b392d31f98b0bf6021f286
#   Stored in directory: /root/.cache/pip/wheels/a7/20/91/33993997db216e7b946d379850c47837d2478be49377a6cb41
#   Building wheel for dynamic-network-architectures (setup.py) ... done
#   Created wheel for dynamic-network-architectures: filename=dynamic_network_architectures-0.3.1-py3-none-any.whl size=30049 sha256=75b3ce301db0a1931567d6ac29c4cd782a6100fdc91e85dc35b56e90633034a2
#   Stored in directory: /root/.cache/pip/wheels/55/1b/13/a6419c8dbf998b9343710355ec3edc5c8e24d9b7b22eec95fb
# Successfully built nnunetv2 acvl-utils batchgeneratorsv2 dynamic-network-architectures
# Installing collected packages: SimpleITK, argparse, yacs, python-gdcm, pydicom, imagecodecs, connected-components-3d, dicom2nifti, fft-conv-pytorch, dynamic-network-architectures, batchgeneratorsv2, acvl-utils, nnunetv2
# Successfully installed SimpleITK-2.4.0 acvl-utils-0.2 argparse-1.4.0 batchgeneratorsv2-0.2.1 connected-components-3d-3.18.0 dicom2nifti-2.4.11 dynamic-network-architectures-0.3.1 fft-conv-pytorch-1.2.0 imagecodecs-2024.9.22 nnunetv2-2.5.1 pydicom-3.0.1 python-gdcm-3.0.24.1 yacs-0.1.8

# %%
# Set up all the parameters required by the metadata generation utility

output_folder = '/content/drive/MyDrive/TCIA/nnUNet/nnUNet_raw/Dataset501_Glioblastoma'
channel_names = {0: 'T1', 1: 'T1GD', 2:'T2', 3: 'FLAIR'}
labels = {'background': 0, 'ET': 1, 'NCR': 2, 'ED': 3}
file_ending = '.nii.gz'
region_class_order = {
  'background': 0,
  'whole tumor': (1, 2, 3),
  'tumor core': (2, 3),
  'enhancing tumor': 3
}
num_training_cases = 117
dataset_name = 'UPENN-GBM'
description = 'UPENN-GBM tumor segmentation'

# %%
from nnunetv2.dataset_conversion.generate_dataset_json import generate_dataset_json
generate_dataset_json(output_folder=output_folder,channel_names=channel_names, labels=labels,
                      file_ending=file_ending,region_class_order=region_class_order,
                      num_training_cases=num_training_cases, dataset_name=dataset_name, description=description)
